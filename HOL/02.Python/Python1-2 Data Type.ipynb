# %% [markdown]
# # Python 변수 규칙

# %% [markdown]
# ### 문자, 숫자, 밑줄 등을 포함 할 수 있다.
# ### 숫자는 제일 처음에 나올 수 없다.
#
# 사용가능한 이름: 	a, b, friends, grunt, var3, _str
# 사용 불가한 이름:	2a, 2_str, hello~, hi!

# %%
a = 1

# %%
b = 2

# %%
2a = 1
# Out:
#   File "<ipython-input-3-91ca527aa26e>", line 1
#     2a = 1
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 대소문자를 구별한다.

# %%
friend = 1

# %%
Friend = 10

# %%
friend
# Out:
# 1

# %%
Friend
# Out:
# 10

# %% [markdown]
# ### 예약어는 사용할 수 없다.
#
# and, as, assert, break, class, continue, def, del, elif, else, except
#  is, finally, for ……

# %%
for = 1
# Out:
#   File "<ipython-input-9-b26be1b49601>", line 1
#     for = 1
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 숫자형

# %% [markdown]
# #### 정수형은 int 형이다.

# %%
year = 2000

# %%
month = 12

# %%
print(year, month)
# Out:
# 2000 12

# %% [markdown]
# ##### 정수 앞에 0o를 붙이면 8진수 0b를 붙이면 2지수로 그리고 0x를 붙이면 16진수로 인식된다.

# %%
0o10
# Out:
# 8

# %%
0b10
# Out:
# 2

# %%
0x10
# Out:
# 16

# %% [markdown]
# ##### 다음은 10진수를 받아서 각 진수로 변환하는 방법입니다. 단 결과는 문자형입니다.

# %%
oct(38)
# Out:
# '0o46'

# %%
hex(38)
# Out:
# '0x26'

# %%
bin(38)
# Out:
# '0b100110'

# %% [markdown]
# ##### 파이썬 2.x에서는 큰 정수를 담기 위해서 별도로 long형이 있었지만 3.x에서는 다 int형으로 통합 되었습니다.

# %%
type(1)
# Out:
# int

# %%
type(2**31)
# Out:
# int

# %% [markdown]
# #### 실수형은 float로 표현됩니다.
# 3.14 또는 314e-2와 같은 형태로 표현 가능합니다.

# %%
type(3.14)
# Out:
# float

# %%
type(314e-2)
# Out:
# float

# %% [markdown]
# #### 실수 보다 조금 더 큰 복소수는 다음과 같이 표현됩니다.

# %%
x = 3 - 4j

# %%
type(x)
# Out:
# complex

# %% [markdown]
# #### 복소수에서 real()은 실수부를 imag()는 허수부를 conjugate()는 켤레복소수를 나타냅니다.

# %%
x.imag
# Out:
# -4.0

# %%
x.real
# Out:
# 3.0

# %%
x.conjugate()
# Out:
# (3+4j)

# %% [markdown]
# ##### 원의 넓이와 삼각형 넓이 구하기

# %%
r = 2

# %%
circle_area = 3.14 * (r ** 2)

# %%
x = 3

# %%
y = 4

# %%
triangle_area = x * y  / 2

# %%
print(circle_area, triangle_area)
# Out:
# 12.56 6.0

# %% [markdown]
# #### 위의 수식에서 3.14 * r ** 2를 해도 결과는 같습니다. 거듭제곱이 그냥 곱셈보다 우선 순위가 높습니다.

# %%
result = 3.14 * r ** 2

# %%
print(result)
# Out:
# 12.56

# %% [markdown]
# ### 문자형 실습

# %%
'Hello Python'
# Out:
# 'Hello Python'

# %%
"Hello Python"
# Out:
# 'Hello Python'

# %%
"Welcome to 'Python World'"
# Out:
# "Welcome to 'Python World'"

# %%
print("""
항상 태양을 바라보아라 
그리하면 너는 그림자를 볼 수 없을 것이다. 

- 헬렌켈러 
""")
# Out:
# 항상 태양을 바라보아라
# 그리하면 너는 그림자를 볼 수 없을 것이다.
#
# - 헬렌켈러

# %%
print("\t탭\n다음줄")
# Out:
# 	탭
# 다음줄

# %%
print(r"\t탭\n다음줄")
# Out:
# \t탭\n다음줄

# %%
'py''thon'
# Out:
# 'python'

# %%
'py' + 'thon'
# Out:
# 'python'

# %%
'py' * 3
# Out:
# 'pypypy'

# %% [markdown]
# #### 파이썬에서 문자열은 자동으로 인덱싱(indexing)이 됩니다.

# %%
a = 'python'

# %%
a
# Out:
# 'python'

# %%
a[0]
# Out:
# 'p'

# %%
a[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-4dd769713adc> in <module>()
# ----> 1 a[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### 문자열 인덱싱은 Read only 입니다.
# #### 범위를 설정할 수도 있습니다. [시작위치:끝위치]

# %%
a[0:1]
# Out:
# 'p'

# %%
a[1:4]
# Out:
# 'yth'

# %%
a[:2]
# Out:
# 'py'

# %%
a[-2:]
# Out:
# 'on'

# %%
a[:]
# Out:
# 'python'

# %%
a[::2]
# Out:
# 'pto'

# %% [markdown]
# #### 데이터 타입의 변환

# %%
str(3.14)
# Out:
# '3.14'

# %%
int('49')
# Out:
# 49

# %%
float(23)
# Out:
# 23.0

# %%
## 유니코드

# %%
type('가')
# Out:
# str

# %%
'가'.encode('utf-8')
# Out:
# b'\xea\xb0\x80'

# %% [markdown]
# #### 어떤 문자의 유니코드 값을 알고 싶거나 혹은 반대의 작업을 할 경우에는 chr() ord()를 사용하면 된다.

# %%
ord('s')
# Out:
# 115

# %%
chr(115)
# Out:
# 's'
