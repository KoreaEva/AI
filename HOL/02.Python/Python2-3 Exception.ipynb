# %% [markdown]
# # 예외처리
# 완전한 프로그램은 없다. 또 프로그램에서 제어하지 못하는 오류들이 있을 수 있다. 그런 오류들을 처리하는 것을 예외처리라고 한다.

# %%
a = [10, 20, 30]

# %%
a[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-f75b6be7d8e3> in <module>()
# ----> 1 a[3]
#
# IndexError: list index out of range

# %%
## 구문에러

# %%
print('{0}, {1}.format(10,20))
# Out:
#   File "<ipython-input-5-014ff9e49009>", line 1
#     print('{0}, {1}.format(10,20))
#                                   ^
# SyntaxError: EOL while scanning string literal

# %%
## 예외

# %%
print(a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6487c9f92f1c> in <module>()
# ----> 1 print(a1)
#
# NameError: name 'a1' is not defined

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-e574edb36883> in <module>()
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
a = 'Apple'

# %%
10/ a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7cc21ac57725> in <module>()
# ----> 1 10/ a
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def divide(a, b):
    return a/b

# %%
divide(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-ccc290a9b5cb> in <module>()
# ----> 1 divide(10, 0)
#
# <ipython-input-16-7507bdc665d5> in divide(a, b)
#       1 def divide(a, b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
try:
    c = divide(5, 0)
except:
    print('Exception is occured!!')
# Out:
# Exception is occured!!

# %%
try:
    c = divide(5, 0)
except ZeroDivisionError:
    print('두 번째 값은 0이 되면 안됩니다.')
except TypeError:
    print('모든 인자는 숫자여야 합니다.')
except:
    print('알 수 없는 오류 입니다.')
finally:
    print('감사합니다. ')
# Out:
# 두 번째 값은 0이 되면 안됩니다.
# 감사합니다.

# %%
## 강제로 예외를 발생 시키는 raise

# %%
def RaiseErrorFunc():
    raise NameError
    
try:
    RaiseErrorFunc()
except:
    print("NameError is Catched")
# Out:
# NameError is Catched
