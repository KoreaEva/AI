# %%
# 문자열(string)

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
# capialize() 첫문자를 대문자로 나머지 문자는 소문자로 바꾼다.

# %%
"PYTHON".capitalize()
# Out:
# 'Python'

# %%
"python is powerful".capitalize()
# Out:
# 'Python is powerful'

# %%
# count(keyword, [start,[end]]) 특정 키워드의 반복 회수를 알려준다.

# %%
'python is powerful'.count('p')
# Out:
# 2

# %%
'python is powerful'.count('p',5)
# Out:
# 1

# %%
### endswith(postfix, [start],[end]) #특정 프리픽스의 여부를 확인한다.

# %%
'python is powerful'.endswith('ful')
# Out:
# True

# %%
'python is powerful'.endswith(('m','l'))
# Out:
# True

# %%
### expandtabs tab을 공백으로 치환한다.

# %%
'python\tis\tpowerful'
# Out:
# 'python\tis\tpowerful'

# %%
'python\tis\tpowerful'.expandtabs()
# Out:
# 'python  is      powerful'

# %%
'python\tis\tpowerful'.expandtabs(1)
# Out:
# 'python is powerful'

# %%
### find(keyword,[start,[end]]) 문자열 키워드가 나타나는 첫 번째 위치를 반환합니다.

# %%
'python is powerful'.find('p')
# Out:
# 0

# %%
'python is powerful'.find('pa')
# Out:
# -1

# %%
### index(keyword, start, [end]) find와 비슷하지만 못 찾으면 오류가 난다.

# %%
'python is powerful'.index('p')
# Out:
# 0

# %%
'python is powerful'.index('pa')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-45cb52e28ce2> in <module>()
# ----> 1 'python is powerful'.index('pa')
#
# ValueError: substring not found

# %%
### isalnum() 알파벳과 숫자 여부를 돌려준다.

# %%
'python'.isalnum()
# Out:
# True

# %%
'python3000'.isalnum()
# Out:
# True

# %%
'python3.6'.isalnum()
# Out:
# False

# %%
## isalphia() 알파벳 여부를 알려준다.

# %%
'python'.isalpha()
# Out:
# True

# %%
'python3000'.isalpha()
# Out:
# False

# %%
### islower() 모든 문자가 소문자인지 알려준다.

# %%
'python'.islower()
# Out:
# True

# %%
'Python'.islower()
# Out:
# False
