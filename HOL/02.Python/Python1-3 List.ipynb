# %% [markdown]
# # 리스트의 실습

# %%
colors = ['red', 'green', 'gold']

# %%
colors
# Out:
# ['red', 'green', 'gold']

# %%
type(colors)
# Out:
# list

# %% [markdown]
# #### 값을 추가 할 때에는 append()를 사용할 수 있습니다.

# %%
colors.append('blue')

# %%
colors
# Out:
# ['red', 'green', 'gold', 'blue']

# %% [markdown]
# #### append()는 마지막에 추가되지만 inert() 원하는 인덱스 뒤에 추가 할 수 있습니다.

# %%
colors.insert(1,'black')

# %%
colors
# Out:
# ['red', 'black', 'green', 'gold', 'blue']

# %% [markdown]
# #### extend() 를 사용하면 한번에 여러개를 추가 할 수 있습니다.

# %%
colors.extend(['white','gray'])

# %%
colors
# Out:
# ['red', 'black', 'green', 'gold', 'blue', 'white', 'gray']

# %% [markdown]
# #### 더하기 연산자도 사용 가능합니다.

# %%
colors += ['red']

# %%
colors
# Out:
# ['red', 'black', 'green', 'gold', 'blue', 'white', 'gray', 'red']

# %%
colors += 'red'

# %%
colors
# Out:
# ['red',
#  'black',
#  'green',
#  'gold',
#  'blue',
#  'white',
#  'gray',
#  'red',
#  'r',
#  'e',
#  'd']

# %% [markdown]
# #### 해당 리스트 안에서 검색할 때에는 index()를 사용할 수 있으며 제일 먼저 찾은 결과만 돌려 줍니다.

# %%
colors.index('red')
# Out:
# 0

# %%
colors.index('red', 1)
# Out:
# 7

# %% [markdown]
# #### count()를 이용해서 갯수를 세거나 혹은 pop()을 사용해서 값을 뽑아내는 것도 가능합니다.

# %%
colors.count('red')
# Out:
# 2

# %%
colors.pop()
# Out:
# 'd'

# %%
colors.pop()
# Out:
# 'e'

# %%
colors.pop(1)
# Out:
# 'black'

# %%
colors
# Out:
# ['red', 'green', 'gold', 'blue', 'white', 'gray', 'red']

# %% [markdown]
# #### remove는 단순히 해당 값을 삭제합니다.

# %%
colors.remove('gold')

# %%
colors
# Out:
# ['red', 'green', 'blue', 'white', 'gray', 'red']

# %% [markdown]
# #### 정렬을 위해서 sort() 혹은 reverse()가 제공됩니다.

# %%
colors.sort()

# %%
colors
# Out:
# ['blue', 'gray', 'green', 'red', 'red', 'white']

# %%
colors.reverse()

# %%
colors
# Out:
# ['white', 'red', 'red', 'green', 'gray', 'blue']

# %% [markdown]
# # 세트 (set)

# %%
a = {1,2,3}

# %%
b = {3,4,5}

# %%
a
# Out:
# {1, 2, 3}

# %%
b
# Out:
# {3, 4, 5}

# %%
type(a)
# Out:
# set

# %% [markdown]
# #### set를 통해서 합집합 혹은 교집합을 구할 수 있다.

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a.intersection(b)
# Out:
# {3}

# %%
a - b #차집합
# Out:
# {1, 2}

# %%
a | b #합집합
# Out:
# {1, 2, 3, 4, 5}

# %%
a & b #교집합
# Out:
# {3}

# %% [markdown]
# # 튜플(tuple)

# %%
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
a, b = 1, 2

# %%
print(a, b)
# Out:
# 1 2

# %%
(a, b) = (1, 2)

# %%
print(a, b)
# Out:
# 1 2

# %% [markdown]
# #### 튜플을 사용하면 swap 예제를 간단하게 해결 할 수 있다.

# %%
a, b = 1, 2

# %%
print(a, b)
# Out:
# 1 2

# %%
a, b = b, a

# %%
print(a, b)
# Out:
# 2 1

# %%
a = set((1,2,3))

# %%
a
# Out:
# {1, 2, 3}

# %%
type(a)
# Out:
# set

# %%
b = list(a)

# %%
b
# Out:
# [1, 2, 3]

# %%
type(b)
# Out:
# list

# %%
c = tuple(b)

# %%
c
# Out:
# (1, 2, 3)

# %%
type(c)
# Out:
# tuple

# %%
d = set(c)

# %%
d
# Out:
# {1, 2, 3}

# %%
type(d)
# Out:
# set

# %% [markdown]
# #### in 연산자를 통해서 해당 값이 있는지 확인 가능하다.

# %%
a = set((1,2,3))

# %%
1 in a
# Out:
# True

# %%
b = list(a)

# %%
2 in b
# Out:
# True

# %%
c = tuple(b)

# %%
3 in c
# Out:
# True

# %%
4 in a
# Out:
# False

# %% [markdown]
# # 사전(Dictionary)

# %%
d = dict(a=1, b=3, c=5)

# %%
d
# Out:
# {'a': 1, 'b': 3, 'c': 5}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# #### dict를 사용하지 않더라도 사전을 생성할 수 있다.

# %%
color = {'apple':'red', 'banana':'yellow'}

# %%
color
# Out:
# {'apple': 'red', 'banana': 'yellow'}

# %%
color['apple']
# Out:
# 'red'

# %%
color[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-b53403da2cb2> in <module>()
# ----> 1 color[0]
#
# KeyError: 0

# %%
color
# Out:
# {'apple': 'red', 'banana': 'yellow'}

# %%
color['cherry'] = 'red'

# %%
color
# Out:
# {'apple': 'red', 'banana': 'yellow', 'cherry': 'red'}

# %%
color['apple'] = 'green'

# %%
color
# Out:
# {'apple': 'green', 'banana': 'yellow', 'cherry': 'red'}

# %% [markdown]
# #### 사전의 모든 내용을 얻으려면 items(), keys(), values()를 사용할 수 있다.

# %%
for c in color.items():
    print(c)
# Out:
# ('apple', 'green')
# ('banana', 'yellow')
# ('cherry', 'red')

# %%
for k, v in color.items():
    print(k, v)
# Out:
# apple green
# banana yellow
# cherry red

# %%
for k in color.keys():
    print(k)
# Out:
# apple
# banana
# cherry

# %%
for v in color.values():
    print(v)
# Out:
# green
# yellow
# red

# %% [markdown]
# #### 사전의 삭제는 'del'을 통해서 하나씩 삭제하거나 clear()를 사용해서 한번에 모두 삭제할 수도 있다.

# %%
color
# Out:
# {'apple': 'green', 'banana': 'yellow', 'cherry': 'red'}

# %%
del color['cherry']

# %%
color
# Out:
# {'apple': 'green', 'banana': 'yellow'}

# %%
color.clear()

# %%
color
# Out:
# {}

# %% [markdown]
# #### 데이터 타입은 서로 혼용해서 사용하는 것이 가능하다.

# %%
{'age':40.5, 'job':[1,2,3],'name':{'Kim':2},'Cho': 1}
# Out:
# {'Cho': 1, 'age': 40.5, 'job': [1, 2, 3], 'name': {'Kim': 2}}

# %%
[1,2,3,('green'),{'apple':1}]
# Out:
# [1, 2, 3, 'green', {'apple': 1}]

# %% [markdown]
# # 부울(bool)

# %%
isRight = False

# %%
type(isRight)
# Out:
# bool

# %%
1 < 2
# Out:
# True

# %%
1 != 2
# Out:
# True

# %%
1 == 2
# Out:
# False

# %% [markdown]
# #### 논리 연산자는 and, or not이 있습니다.

# %%
True and False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False | False
# Out:
# False

# %%
not True
# Out:
# False

# %% [markdown]
# # 얕은 복사와 깊은 복사

# %%
a = [1,2,3]

# %%
b = a

# %%
a[0] = 38

# %%
a
# Out:
# [38, 2, 3]

# %%
b
# Out:
# [38, 2, 3]

# %%
id(a)
# Out:
# 140079195465608

# %%
id(b)
# Out:
# 140079195465608

# %%
a = [1,2,3,]

# %%
b = a[:]

# %%
a[0] = 38

# %%
a
# Out:
# [38, 2, 3]

# %%
b
# Out:
# [1, 2, 3]

# %% [markdown]
# #### copy module을 사용하는 방법도 있다.

# %%
import copy

# %%
a = [1,2,3]

# %%
b = copy.deepcopy(a)

# %%
a[0] = 38

# %%
a
# Out:
# [38, 2, 3]

# %%
b
# Out:
# [1, 2, 3]
