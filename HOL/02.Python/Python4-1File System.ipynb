# %% [markdown]
# # File System 다루기

# %%
import os.path

# %% [markdown]
# ## os.path
# 현재 경로에 대한 정보를 제공해 준다.

# %%
os.path.abspath('.')
# Out:
# '/home/nbuser/library/Documents/Chapter4'

# %%
from os.path import *

# %%
abspath('.') #현재경로를 알려준다.
# Out:
# '/home/nbuser/library/Documents/Chapter4'

# %%
basename('/home/nbuser/library/Documents/Chapter4') #기준 디렉토리 정보
# Out:
# 'Chapter4'

# %%
exists('../Chapter4') #폴더의 존재 여부
# Out:
# True

# %%
getsize('../Chapter4') #Size를 알려준다.
# Out:
# 0
